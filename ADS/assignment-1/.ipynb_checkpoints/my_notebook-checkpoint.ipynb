# 21585          False     False         False    False  False  False
# 21586          False     False         False    False  False  False
# 21587          False     False         False    False  False  False
# 21588          False     False         False    False  False  False
# 21589          False     False         False    False  False  False
# 21590          False     False         False    False  False  False
# 21591          False     False         False    False  False  False
# 21592          False     False         False    False  False  False
# 21593          False     False         False    False  False  False
# 21594          False     False         False    False  False  False
# 21595          False     False         False    False  False  False
# 21596          False     False         False    False  False  False
# 21597          False     False         False    False  False  False
# 21598          False     False         False    False  False  False
# 21599          False     False         False    False  False  False
# 21600          False     False         False    False  False  False
# 21601          False     False         False    False  False  False
# 21602          False     False         False    False  False  False
# 21603          False     False         False    False  False  False
# 21604          False     False         False    False  False  False
# 21605          False     False         False    False  False  False
# 21606          False     False         False    False  False  False
# 21607          False     False         False    False  False  False
# 21608          False     False         False    False  False  False
# 21609          False     False         False    False  False  False
# 21610          False     False         False    False  False  False
# 21611          False     False         False    False  False  False
# 21612          False     False         False    False  False  False
#
#        sqft_living15  sqft_lot15
# 0              False       False
# 1              False       False
# 2              False       False
# 3              False       False
# 4              False       False
# 5              False       False
# 6              False       False
# 7              False       False
# 8              False       False
# 9              False       False
# 10             False       False
# 11             False       False
# 12             False       False
# 13             False       False
# 14             False       False
# 15             False       False
# 16             False       False
# 17             False       False
# 18             False       False
# 19             False       False
# 20             False       False
# 21             False       False
# 22             False       False
# 23             False       False
# 24             False       False
# 25             False       False
# 26             False       False
# 27             False       False
# 28             False       False
# 29             False       False
# ...              ...         ...
# 21583          False       False
# 21584          False       False
# 21585          False       False
# 21586          False       False
# 21587          False       False
# 21588          False       False
# 21589          False       False
# 21590          False       False
# 21591          False       False
# 21592          False       False
# 21593          False       False
# 21594          False       False
# 21595          False       False
# 21596          False       False
# 21597          False       False
# 21598          False       False
# 21599          False       False
# 21600          False       False
# 21601          False       False
# 21602          False       False
# 21603          False       False
# 21604          False       False
# 21605          False       False
# 21606          False       False
# 21607          False       False
# 21608          False       False
# 21609          False       False
# 21610          False       False
# 21611          False       False
# 21612          False       False
#
# [21613 rows x 21 columns]

# %%
df.get_dtype_counts()
# Out:
# float64     5
# int64      15
# object      1
# dtype: int64

# %%
# for column in df.isna():
#     select = df.isna()[column]
#     print("missing values in column ",column, len(df[column][select]))
# select  = df.apply(lambda r : any([e for e in r  ]),axis=1)
# for column in select:
# print(len(select))
# print(df_copy[select])
# df_with_no_strings = df[~rows_with_strings]
cols_with_missing = [col for col in df.columns 
                                 if df[col].isnull().any() or df[col].isna().any()]
print("missing value columns")
print(cols_with_missing)
# Out:
# missing value columns
# []

# %% [markdown]
# #### Well that means our dataset does not have any missing values

# %% [markdown]
# ### Identifying placeholder data

# %%
df.head()
# Doing. Isn't done yet.
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0              0      1955             0    98178  47.5112 -122.257
# 1            400      1951          1991    98125  47.7210 -122.319
# 2              0      1933             0    98028  47.7379 -122.233
# 3            910      1965             0    98136  47.5208 -122.393
# 4              0      1987             0    98074  47.6168 -122.045
#
#    sqft_living15  sqft_lot15
# 0           1340        5650
# 1           1690        7639
# 2           2720        8062
# 3           1360        5000
# 4           1800        7503
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Identifying outliers

# %%
from collections import Counter, defaultdict
def checkOutlier(df, m = 4):
    uniOutlier = dict().fromkeys(df.columns, None)
    outSample = abs(df - df.mean()) > 4 * df.std()
    outSum = (abs(df - df.mean()) > 4 * df.std()).sum()
    for key in uniOutlier.keys():
        uniOutlier[key] = set(outSample.index[outSample.loc[:, key]])
    outportion = outSum / df.shape[0]
    #print("No outlier Vars: " ,outSum.index[outportion == 0].tolist())
    #print("Outlier Portion")
    #print(outportion[outportion != 0].index.tolist())
    #print(outportion[outportion != 0].values.tolist())
    outportion = outportion[outportion != 0].sort_values()
    outlierLst = outportion.index.tolist()
    return uniOutlier, outlierLst

from collections import Counter
def outlierCounter(outlierDict, exceptionLst = ['price']):
    inter = Counter()
    name = defaultdict(list)
    coreKey = set(outlierDict.keys()).difference(exceptionLst)
    for key in coreKey:
        value = outlierDict[key]
        for val in value:
            inter[val] += 1
            name[val].append(key)
    res = pd.DataFrame([inter, name], index = ['count', 'variable']).T
    print(res)
    res = res.sort_values('count', ascending = False)
    print(res)
    return res

from scipy.stats import multivariate_normal
def bivarCI(dfNum, y = 'price', outer = 10, z_score = 0.00006, cols = 2):
    
    colNum = dfNum.shape[1]
    row, col = divmod(colNum-1, cols)
    if row == 1 and col == 0: row += 1
    if col != 0: row += 1
    
    
    z_under = z_score * 0.98
    z_upper = z_score * 1.02
    
    biOutlier = dict().fromkeys(dfNum.columns, None)
    #f, axes = plt.subplots(row, cols, figsize = (4*cols, 4*row))
    #f.suptitle('Bivaraite CI', fontsize = 12)
    for ix, var1 in enumerate(dfNum.columns):
        if var1 == y: break
        r,c = divmod(ix, cols)
        dfPart = dfNum.loc[:, [var1,y]]
        dfPart = dfPart[~dfPart.isnull()].copy()
        dfPart = dfPart.loc[dfPart.loc[:, var1] != 0,:]
        dfPart = (dfPart - dfPart.mean()) / dfPart.std()
        F, X, Y, posProb = bivarConverter(dfPart, outer, z_under, z_upper, N = 700)
        #axes[r,c].contourf(X, Y, posProb)
        #axes[r,c].scatter(dfPart.loc[:, var1], dfPart.loc[:, y], alpha = 1)
        #axes[r,c].set_title('Bivaraite CI ' + var1)
        dfPartProb = F.pdf(dfPart.values)
        outIndex = dfPart.index[dfPartProb < z_score]
        biOutlier[var1] = set(outIndex.tolist())
    #f.tight_layout(rect = [0, 0.03, 1, 0.95])
    #plt.show()
    
    return biOutlier

def bivarConverter(df, outer, z_under, z_upper, N = 500):
    x_init, y_init = df.min() - outer
    x_end, y_end = df.max() + outer
    X = np.linspace(x_init, x_end, N)
    Y = np.linspace(y_init, y_end, N)
    X, Y = np.meshgrid(X, Y)
    pos = np.empty(X.shape + (2,))
    pos[:,:,0] = X
    pos[:,:,1] = Y
    F = multivariate_normal(mean=df.mean().values, cov=df.corr().values)
    posProb = F.pdf(pos)
    posProb[(z_under < posProb) & (posProb < z_upper)] = 1
    posProb[(z_under > posProb) | (posProb < z_upper)] = 0
       
    return F , X, Y, posProb

# %%
cols = ['sqft_living15', 'sqft_lot', 'sqft_living', 'sqft_basement', 'price']
uniOutlier, outlierList = checkOutlier(df.loc[:, cols])
uniOut = outlierCounter(uniOutlier, ['price'])
# Out:
#       count                                variable
# 5         1                         [sqft_living15]
# 145       1                              [sqft_lot]
# 238       1                              [sqft_lot]
# 380       1                              [sqft_lot]
# 419       1                           [sqft_living]
# 443       1                              [sqft_lot]
# 484       1                              [sqft_lot]
# 519       1                              [sqft_lot]
# 527       2                 [sqft_living, sqft_lot]
# 561       1                              [sqft_lot]
# 577       1                           [sqft_living]
# 590       1                              [sqft_lot]
# 681       1                              [sqft_lot]
# 762       1                              [sqft_lot]
# 858       1                              [sqft_lot]
# 929       1                              [sqft_lot]
# 1008      1                              [sqft_lot]
# 1045      1                              [sqft_lot]
# 1100      2            [sqft_living15, sqft_living]
# 1123      1                         [sqft_living15]
# 1164      1                           [sqft_living]
# 1199      1                         [sqft_basement]
# 1315      2            [sqft_living, sqft_basement]
# 1324      1                              [sqft_lot]
# 1448      1                           [sqft_living]
# 1530      1                         [sqft_living15]
# 1539      1                           [sqft_living]
# 1586      1                         [sqft_living15]
# 1624      1                              [sqft_lot]
# 1653      1                              [sqft_lot]
# ...     ...                                     ...
# 20005     1                         [sqft_basement]
# 20141     1                              [sqft_lot]
# 20203     1                              [sqft_lot]
# 20267     2               [sqft_living15, sqft_lot]
# 20386     1                              [sqft_lot]
# 20421     1                              [sqft_lot]
# 20425     1                              [sqft_lot]
# 20441     2            [sqft_living15, sqft_living]
# 20452     2                 [sqft_living, sqft_lot]
# 20460     1                         [sqft_basement]
# 20471     2                 [sqft_living, sqft_lot]
# 20499     1                              [sqft_lot]
# 20563     2            [sqft_living15, sqft_living]
# 20578     1                           [sqft_living]
# 20664     1                           [sqft_living]
# 20811     1                              [sqft_lot]
# 20830     2            [sqft_living15, sqft_living]
# 20838     2            [sqft_living, sqft_basement]
# 20920     1                              [sqft_lot]
# 20923     1                           [sqft_living]
# 20974     1                              [sqft_lot]
# 21050     1                           [sqft_living]
# 21325     1                              [sqft_lot]
# 21333     1                         [sqft_living15]
# 21344     3  [sqft_living, sqft_basement, sqft_lot]
# 21351     1                              [sqft_lot]
# 21506     1                           [sqft_living]
# 21520     1                         [sqft_living15]
# 21540     1                         [sqft_living15]
# 21548     1                              [sqft_lot]
#
# [446 rows x 2 columns]
#       count                                           variable
# 12777     4  [sqft_living15, sqft_living, sqft_basement, sq...
# 7035      3        [sqft_living15, sqft_living, sqft_basement]
# 21344     3             [sqft_living, sqft_basement, sqft_lot]
# 2236      3        [sqft_living15, sqft_living, sqft_basement]
# 15482     3        [sqft_living15, sqft_living, sqft_basement]
# 2713      3        [sqft_living15, sqft_living, sqft_basement]
# 11685     3             [sqft_living, sqft_basement, sqft_lot]
# 18414     2                       [sqft_living, sqft_basement]
# 7346      2                       [sqft_living15, sqft_living]
# 14556     2                       [sqft_living, sqft_basement]
# 10085     2                       [sqft_living, sqft_basement]
# 12370     2                       [sqft_living15, sqft_living]
# 19858     2                       [sqft_living15, sqft_living]
# 15828     2                     [sqft_living15, sqft_basement]
# 2125      2                       [sqft_living, sqft_basement]
# 2444      2                       [sqft_living, sqft_basement]
# 4967      2                       [sqft_living15, sqft_living]
# 3914      2                       [sqft_living, sqft_basement]
# 19215     2                       [sqft_living, sqft_basement]
# 7252      2                       [sqft_living, sqft_basement]
# 8092      2                       [sqft_living, sqft_basement]
# 20267     2                          [sqft_living15, sqft_lot]
# 16430     2                       [sqft_living15, sqft_living]
# 3020      2                       [sqft_living, sqft_basement]
# 4411      2                       [sqft_living, sqft_basement]
# 3100      2                            [sqft_living, sqft_lot]
# 16773     2                            [sqft_living, sqft_lot]
# 18594     2                            [sqft_living, sqft_lot]
# 15049     2                       [sqft_living, sqft_basement]
# 10318     2                          [sqft_basement, sqft_lot]
# ...     ...                                                ...
# 5722      1                                         [sqft_lot]
# 5719      1                                         [sqft_lot]
# 5702      1                                      [sqft_living]
# 6965      1                                         [sqft_lot]
# 7059      1                                         [sqft_lot]
# 7907      1                                      [sqft_living]
# 7487      1                                         [sqft_lot]
# 7846      1                                    [sqft_basement]
# 7845      1                                    [sqft_basement]
# 7833      1                                         [sqft_lot]
# 7811      1                                         [sqft_lot]
# 7787      1                                         [sqft_lot]
# 7769      1                                         [sqft_lot]
# 7647      1                                         [sqft_lot]
# 7552      1                                         [sqft_lot]
# 7516      1                                         [sqft_lot]
# 7496      1                                    [sqft_basement]
# 7458      1                                    [sqft_living15]
# 7070      1                                         [sqft_lot]
# 7341      1                                         [sqft_lot]
# 7294      1                                         [sqft_lot]
# 7282      1                                         [sqft_lot]
# 7281      1                                         [sqft_lot]
# 7280      1                                         [sqft_lot]
# 7270      1                                    [sqft_living15]
# 7269      1                                    [sqft_living15]
# 7250      1                                         [sqft_lot]
# 7191      1                                      [sqft_living]
# 7077      1                                         [sqft_lot]
# 21548     1                                         [sqft_lot]
#
# [446 rows x 2 columns]

# %%
def outliers_z_score(ys):
    threshold = 3

    mean_y = np.mean(ys)
    stdev_y = np.std(ys)
    z_scores = [(y - mean_y) / stdev_y for y in ys]
    return np.where(np.abs(z_scores) > threshold)

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
cols = ['sqft_living15', 'sqft_lot', 'sqft_living', 'sqft_basement', 'price']
uniOutlier, outlierList = checkOutlier(df.loc[:, cols])
uniOut = outlierCounter(uniOutlier, ['price'])
biOutlier = bivarCI(df.loc[:, cols], outer = 2, z_score = 0.00006,  cols = 4)
biOut = outlierCounter(biOutlier, ['price', ])
totOut = uniOut.join(biOut, lsuffix='_uni', rsuffix='_bi')
print('Top 3 Outlier')
totOut.head(3)
# Out:
# Top 3 Outlier
#       count_uni                                       variable_uni count_bi  \
# 12777         4  [sqft_living15, sqft_living, sqft_basement, sq...        4
# 7035          3        [sqft_living15, sqft_living, sqft_basement]        4
# 21344         3             [sqft_living, sqft_basement, sqft_lot]        3
#
#                                              variable_bi
# 12777  [sqft_living15, sqft_living, sqft_basement, sq...
# 7035   [sqft_living15, sqft_living, sqft_basement, sq...
# 21344             [sqft_living, sqft_basement, sqft_lot]
